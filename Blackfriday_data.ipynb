# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#plt.rcParams['figure.figsize'] = (12, 6)

# %%
train=pd.read_csv("C:/Users/a3dullahi/Dropbox/PC/Desktop/blackfriday/train.csv")
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
test = pd.read_csv("C:/Users/a3dullahi/Dropbox/PC/Desktop/blackfriday/test.csv")
test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df = pd.concat([train, test], ignore_index=True)
df.shape
# Out:
# (783667, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(['User_ID'], axis = 1, inplace = True)
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 783662  P00118942      F  26-35          15             B
# 783663  P00254642      F  26-35          15             B
# 783664  P00031842      F  26-35          15             B
# 783665  P00124742      F  46-50           1             C
# 783666  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
#Handling categorical features Gender
df['Gender']=df['Gender'].map({'F':0, 'M':1})
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#Handling categorical features Age
#pd.get_dummies(df['Age'],drop_first=True)
df['Age'] = df['Age'].map({'0-17':1,'18-25':2 ,'26-35':3, '36-45':4, '46-50':5, '51-55':6, '55+':7})
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
 # Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'City_Category'. 
df['City_Category']= label_encoder.fit_transform(df['City_Category']) 
  
df['City_Category'].unique()
# Out:
# array([0, 2, 1])

# %%
#pinpointing columns with missing values
[factor for factor in df.columns if df[factor].isnull().sum()>0]
# Out:
# ['Product_Category_2', 'Product_Category_3', 'Purchase']

# %%
#
df.isnull().sum()/df.shape[0]*100
# Out:
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.388587
# Product_Category_3            69.648078
# Purchase                      29.808452
# dtype: float64

# %%
#This is a discrete feature. It's best to replace null values with the mode.
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
# Fill missing values in 'Product_Category_2' column with the mode
df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0], inplace=True)

# %%
#This is also a discrete feature.
df['Product_Category_3'].unique()
df['Product_Category_3'].mode()
# Fill missing values in 'Product_Category_3' column with the mode
df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0], inplace=True)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              0
# 1  P00248942       0    1          10              0
# 2  P00087842       0    1          10              0
# 3  P00085442       0    1          10              0
# 4  P00285442       1    7          16              2
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# ...

# %%
# Replace '+' character with an empty string
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+', '')
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              0
# 1  P00248942       0    1          10              0
# 2  P00087842       0    1          10              0
# 3  P00085442       0    1          10              0
# 4  P00285442       1    7          16              2
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                          4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# ...

# %%
# Convert 'Stay_In_Current_City_Years' column to int type
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  int32
#  5   Stay_In_Current_City_Years  783667 non-null  int32
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(3), int32(2), int64(5), object(1)
# memory usage: 59.8+ MB

# %%
#sns.pairplot(df)

# %%
# Plot the barplot
sns.barplot(x='Age', y='Purchase', hue='Gender', data=df)

# Add a title
plt.title("Average Purchase")

# Add labels to the axes
plt.xlabel("Age")
plt.ylabel("Average Purchase Amount")

# Show the plot
plt.show()

# %% [markdown]
# ### According to the analysis of purchase data, it appears that males tend to buy more items compared to females, regardless of age. Additionally, age does not appear to significantly influence purchase behavior, as the average purchase amount remains consistent across different age groups within each gender.

# %%
# Plot the barplot
sns.barplot(x='Occupation', y='Purchase', hue='Age', data=df)

# Add a title
plt.title("Average Purchase")

# Add labels to the axes
plt.xlabel("Occupation")
plt.ylabel("Average Purchase Amount")

# Show the plot
plt.show()

# %%
# Plot the barplot
sns.barplot(x='Product_Category_1', y='Purchase', hue='Age', data=df)

# Add a title
plt.title("Average Purchase")

# Add labels to the axes
plt.xlabel("Product_Category_1")
plt.ylabel("Average Purchase Amount")

# Show the plot
plt.show()

# %%
# Plot the barplot
sns.barplot(x='Product_Category_2', y='Purchase', hue='Age', data=df)

# Add a title
plt.title("Average Purchase")

# Add labels to the axes
plt.xlabel("Product_Category_2")
plt.ylabel("Average Purchase Amount")

# Show the plot
plt.show()

# %%
# Plot the barplot
sns.barplot(x='Product_Category_3', y='Purchase', hue='Age', data=df)

# Add a title
plt.title("Average Purchase")

# Add labels to the axes
plt.xlabel("Product_Category_3")
plt.ylabel("Average Purchase Amount")

# Show the plot
plt.show()

# %%
#feature scaling
df_test = df[df['Purchase'].isnull()]
df_test
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 550068  P00128942       1    5           7              1
# 550069  P00113442       1    3          17              2
# 550070  P00288442       0    4           1              1
# 550071  P00145342       0    4           1              1
# 550072  P00053842       0    3           1              2
# ...           ...     ...  ...         ...            ...
# 783662  P00118942       0    3          15              1
# 783663  P00254642       0    3          15              1
# 783664  P00031842       0    3          15              1
# 783665  P00124742       0    5           1              2
# 783666  P00316642       0    5           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550068                           2               1                   1
# 550069                           0               0                   3
# ...

# %%
df_train = df[~df['Purchase'].isnull()]
df_train
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 0       P00069042       0    1          10              0
# 1       P00248942       0    1          10              0
# 2       P00087842       0    1          10              0
# 3       P00085442       0    1          10              0
# 4       P00285442       1    7          16              2
# ...           ...     ...  ...         ...            ...
# 550063  P00372445       1    6          13              1
# 550064  P00375436       0    3           1              2
# 550065  P00375436       0    3          15              1
# 550066  P00375436       0    7           1              2
# 550067  P00371644       0    5           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# ...

# %%
X = df_train.drop(['Purchase', 'Product_ID'], axis=1)
X.head()
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0    1          10              0                           2
# 1       0    1          10              0                           2
# 2       0    1          10              0                           2
# 3       0    1          10              0                           2
# 4       1    7          16              2                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
